# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Load the dataset

import pandas as pd

url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
df_file1 = pd.read_csv(url)

url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
df_file2 = pd.read_csv(url)

url = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'
df_file3 = pd.read_csv(url)

# %%
# Combine the three datasets
pd.concat([df_file1, df_file2, df_file3], axis=0)
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN    NaN              Bachelor
# 7066  PK87824         NaN    NaN               College
# 7067  TD14365         NaN    NaN              Bachelor
# 7068  UP19263         NaN    NaN               College
# 7069  Y167826         NaN    NaN               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#New data frame combining the information from the 3 files
df_new = pd.concat([df_file1, df_file2, df_file3])
df_new
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN    NaN              Bachelor
# 7066  PK87824         NaN    NaN               College
# 7067  TD14365         NaN    NaN              Bachelor
# 7068  UP19263         NaN    NaN               College
# 7069  Y167826         NaN    NaN               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# #Cleaning the data in the new dataframe

# %%
#st replaced for State
df_new.rename(columns= {'ST': 'State'}, inplace=True)
df_new.rename(columns= {'GENDER': 'Gender'}, inplace=True)
df_new.head(0)
# Out:
# Empty DataFrame
# Columns: [Customer, State, Gender, Education, Customer Lifetime Value, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Vehicle Class, Total Claim Amount, State, Gender]
# Index: []

# %%
#Check duplicated columns
df_new.columns[df_new.columns.duplicated()]
# Out:
# Index(['State', 'Gender'], dtype='str')

# %%
#Check first duplicated column
df_new["State"]
# Out:
#            State       State
# 0     Washington         NaN
# 1        Arizona         NaN
# 2         Nevada         NaN
# 3     California         NaN
# 4     Washington         NaN
# ...          ...         ...
# 7065         NaN  California
# 7066         NaN  California
# 7067         NaN  California
# 7068         NaN  California
# 7069         NaN  California
#
# [12074 rows x 2 columns]

# %%
df_new["State"].head(10)
# Out:
#         State State
# 0  Washington   NaN
# 1     Arizona   NaN
# 2      Nevada   NaN
# 3  California   NaN
# 4  Washington   NaN
# 5      Oregon   NaN
# 6      Oregon   NaN
# 7     Arizona   NaN
# 8      Oregon   NaN
# 9      Oregon   NaN

# %%
#Antes de substituir as colunas originais, precisamos saber se existem linhas em que as duas State possuem valores ao mesmo tempo.
states = df_new["State"]

states.notna().sum(axis=1).value_counts()

#Isso significa que 9.137 linhas têm exatamente um valor de State entre as duas colunas, e 2.937 linhas não têm valor em nenhuma das duas. O mais importante: não apareceu 2, então não há linhas em que as duas colunas State estejam preenchidas ao mesmo tempo. Portanto, podemos combiná-las sem conflito.
# Out:
# 1    9137
# 0    2937
# Name: count, dtype: int64

# %%
#Save new column State with the rows combined
state_combined = df_new["State"].bfill(axis=1).iloc[:, 0]

# %%
#Remove the 2 columns named State
df_new = df_new.drop(columns="State")

# %%
#Add new combined column
df_new["State"] = state_combined
df_new["State"].head(10)
# Out:
# 0    Washington
# 1       Arizona
# 2        Nevada
# 3    California
# 4    Washington
# 5        Oregon
# 6        Oregon
# 7       Arizona
# 8        Oregon
# 9        Oregon
# Name: State, dtype: str

# %%
#Check remaining duplicated columns
df_new.columns[df_new.columns.duplicated()]
# Out:
# Index(['Gender'], dtype='str')

# %%
#Check columns Gender before consolidate 
genders = df_new["Gender"]

genders.notna().sum(axis=1).value_counts()
# Out:
# 1    9015
# 0    3059
# Name: count, dtype: int64

# %%
#Save new column Gender with the rows combined
gender_combined = df_new["Gender"].bfill(axis=1).iloc[:, 0]

# %%
#Remove the 2 columns named Gender
df_new = df_new.drop(columns="Gender")

# %%
#Add new combined column
df_new["Gender"] = gender_combined

# %%
df_new.shape
# Out:
# (12074, 11)

# %%
#Check all columns
df_new.head()
# Out:
#   Customer             Education Customer Lifetime Value   Income  \
# 0  RB50392                Master                     NaN      0.0
# 1  QZ44356              Bachelor              697953.59%      0.0
# 2  AI49188              Bachelor             1288743.17%  48767.0
# 3  WW63253              Bachelor              764586.18%      0.0
# 4  GA49547  High School or Below              536307.65%  36357.0
#
#    Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                1000.0                    1/0/00   Personal Auto
# 1                  94.0                    1/0/00   Personal Auto
# 2                 108.0                    1/0/00   Personal Auto
# 3                 106.0                    1/0/00  Corporate Auto
# 4                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount       State Gender
# 0  Four-Door Car            2.704934  Washington    NaN
# 1  Four-Door Car         1131.464935     Arizona      F
# ...

# %%
#checking STATE column values
df_new["State"].unique()
# Out:
# <StringArray>
# ['Washington',    'Arizona',     'Nevada', 'California',     'Oregon',
#        'Cali',         'AZ',         'WA',          nan]
# Length: 9, dtype: str

# %%
#State mapping dictionary
state_mapping = {
    "AZ": "Arizona",
    "Cali": "California",
    "WA": "Washington"
}

# %%
#Replacing the values in the STATE column
df_new["State"] = df_new["State"].replace(state_mapping)
df_new["State"].unique()
# Out:
# <StringArray>
# ['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', nan]
# Length: 6, dtype: str

# %%
#Checkind Education column values
df_new["Education"].unique()
# Out:
# <StringArray>
# [              'Master',             'Bachelor', 'High School or Below',
#               'College',            'Bachelors',               'Doctor',
#                     nan]
# Length: 7, dtype: str

# %%
df_new["Education"] = df_new["Education"] .replace({"Bachelors": "Bachelor"})
df_new["Education"].unique()
# Out:
# <StringArray>
# ['Master', 'Bachelor', 'High School or Below', 'College', 'Doctor', nan]
# Length: 6, dtype: str

# %%
#checking Customer Lifetime Value
df_new["Customer Lifetime Value"].head()
# Out:
# 0            NaN
# 1     697953.59%
# 2    1288743.17%
# 3     764586.18%
# 4     536307.65%
# Name: Customer Lifetime Value, dtype: object

# %%
#vehicle class
df_new["Vehicle Class"].unique()
# Out:
# <StringArray>
# ['Four-Door Car',  'Two-Door Car',           'SUV',    'Luxury SUV',
#     'Sports Car',    'Luxury Car',             nan]
# Length: 7, dtype: str

# %%
# vehicle class: Sports Car", "Luxury SUV" and "Luxury Car" replaced by "Luxury"
df_new["Vehicle Class"] = df_new["Vehicle Class"].replace({"Sports Car": "Luxury", "Luxury SUV": "Luxury", "Luxury Car": "Luxury"})
df_new["Vehicle Class"].unique()
# Out:
# <StringArray>
# ['Four-Door Car', 'Two-Door Car', 'SUV', 'Luxury', nan]
# Length: 5, dtype: str

# %%
#Checking GENDER column values
df_new["Gender"].value_counts()
# Out:
# Gender
# F         4560
# M         4368
# Male        40
# female      30
# Femal       17
# Name: count, dtype: int64

# %%
# Fixing Gender column 
df_new["Gender"] = df_new["Gender"].replace({"Male": "M", "Female": "F", "Femal": "F", "female": "F" , "Female": "F"})

df_new["Gender"].value_counts()
# Out:
# Gender
# F    4607
# M    4408
# Name: count, dtype: int64

# %%
df_final = df_new.copy()
df_final.shape
df_final.head()
# Out:
#   Customer             Education Customer Lifetime Value   Income  \
# 0  RB50392                Master                     NaN      0.0
# 1  QZ44356              Bachelor              697953.59%      0.0
# 2  AI49188              Bachelor             1288743.17%  48767.0
# 3  WW63253              Bachelor              764586.18%      0.0
# 4  GA49547  High School or Below              536307.65%  36357.0
#
#    Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                1000.0                    1/0/00   Personal Auto
# 1                  94.0                    1/0/00   Personal Auto
# 2                 108.0                    1/0/00   Personal Auto
# 3                 106.0                    1/0/00  Corporate Auto
# 4                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount       State Gender
# 0  Four-Door Car            2.704934  Washington    NaN
# 1  Four-Door Car         1131.464935     Arizona      F
# ...

# %%
df_final.duplicated().sum()
# Out:
# np.int64(2939)

# %%
df_final[df_final.duplicated(keep=False)].head(20)
# Out:
#      Customer Education Customer Lifetime Value   Income  \
# 1068  GS98873  Bachelor              323912.47%  16061.0
# 1069  CW49887    Master              462680.11%  79487.0
# 1070  MY31220   College              899704.02%  54230.0
# 1071      NaN       NaN                     NaN      NaN
# 1072      NaN       NaN                     NaN      NaN
# 1073      NaN       NaN                     NaN      NaN
# 1074      NaN       NaN                     NaN      NaN
# 1075      NaN       NaN                     NaN      NaN
# 1076      NaN       NaN                     NaN      NaN
# 1077      NaN       NaN                     NaN      NaN
# 1078      NaN       NaN                     NaN      NaN
# 1079      NaN       NaN                     NaN      NaN
# 1080      NaN       NaN                     NaN      NaN
# 1081      NaN       NaN                     NaN      NaN
# 1082      NaN       NaN                     NaN      NaN
# ...

# %%
df_final = df_final.dropna(how="all")
df_final = df_final.reset_index(drop=True)

df_final.duplicated().sum()
# Out:
# np.int64(3)

# %%
df_final[df_final.duplicated(keep=False)]
# Out:
#      Customer Education Customer Lifetime Value   Income  \
# 1068  GS98873  Bachelor              323912.47%  16061.0
# 1069  CW49887    Master              462680.11%  79487.0
# 1070  MY31220   College              899704.02%  54230.0
# 1071  GS98873  Bachelor              323912.47%  16061.0
# 1072  CW49887    Master              462680.11%  79487.0
# 1073  MY31220   College              899704.02%  54230.0
#
#       Monthly Premium Auto Number of Open Complaints    Policy Type  \
# 1068                  88.0                    1/0/00  Personal Auto
# 1069                 114.0                    1/0/00   Special Auto
# 1070                 112.0                    1/0/00  Personal Auto
# 1071                  88.0                    1/0/00  Personal Auto
# 1072                 114.0                    1/0/00   Special Auto
# 1073                 112.0                    1/0/00  Personal Auto
#
#       Vehicle Class  Total Claim Amount       State Gender
# ...

# %%
df_final = df_final.drop_duplicates(keep="first")

# %%
df_final = df_final.reset_index(drop=True)

# %%
df_final.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_final.shape
# Out:
# (9134, 11)

# %%
df_final.dtypes
# Out:
# Customer                         str
# Education                        str
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                      str
# Vehicle Class                    str
# Total Claim Amount           float64
# State                            str
# Gender                           str
# dtype: object

# %%
df_final["Customer Lifetime Value"] = (df_final["Customer Lifetime Value"].str.replace("%", ""))
df_final["Customer Lifetime Value"].head()
# Out:
# 0           NaN
# 1     697953.59
# 2    1288743.17
# 3     764586.18
# 4     536307.65
# Name: Customer Lifetime Value, dtype: object

# %%
df_final["Customer Lifetime Value"].dtype
# Out:
# dtype('O')

# %%
df_final["Customer Lifetime Value"] = pd.to_numeric(df_final["Customer Lifetime Value"])
df_final["Customer Lifetime Value"].dtype
# Out:
# dtype('float64')

# %%
df_final["Number of Open Complaints"].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', 0, 2,
#        3, 1, 5, 4], dtype=object)

# %%
for x in df_final["Number of Open Complaints"].unique():
    if isinstance(x, str) and "/" not in x:
        print(repr(x))
# Out:
# '0'
# '2'
# '1'
# '3'
# '5'
# '4'

# %%
df_final["Number of Open Complaints"] = df_final["Number of Open Complaints"].apply(
    lambda x: x.split("/")[1] if isinstance(x, str) and "/" in x else x
)

# %%
df_final["Number of Open Complaints"].unique()
# Out:
# array(['0', '2', '1', '3', '5', '4', 0, 2, 3, 1, 5, 4], dtype=object)

# %%
df_final["Number of Open Complaints"] = pd.to_numeric(
    df_final["Number of Open Complaints"]
)
df_final["Number of Open Complaints"].unique()
# Out:
# array([0, 2, 1, 3, 5, 4])

# %%
df_final.dtypes
df_final.isnull().sum()
# Out:
# Customer                        0
# Education                       0
# Customer Lifetime Value      7077
# Income                          0
# Monthly Premium Auto            0
# Number of Open Complaints       0
# Policy Type                     0
# Vehicle Class                   0
# Total Claim Amount              0
# State                           0
# Gender                        122
# dtype: int64

# %%
df_final["Customer Lifetime Value"].count()
df_final["Customer Lifetime Value"].describe()
df_final[df_final["Customer Lifetime Value"].notna()].head()
# Out:
#   Customer             Education  Customer Lifetime Value   Income  \
# 1  QZ44356              Bachelor                697953.59      0.0
# 2  AI49188              Bachelor               1288743.17  48767.0
# 3  WW63253              Bachelor                764586.18      0.0
# 4  GA49547  High School or Below                536307.65  36357.0
# 5  OC83172              Bachelor                825629.78  62902.0
#
#    Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# 1                  94.0                          0   Personal Auto
# 2                 108.0                          0   Personal Auto
# 3                 106.0                          0  Corporate Auto
# 4                  68.0                          0   Personal Auto
# 5                  69.0                          0   Personal Auto
#
#    Vehicle Class  Total Claim Amount       State Gender
# 1  Four-Door Car         1131.464935     Arizona      F
# ...

# %%
df_final["Customer Lifetime Value"] = (
    df_final["Customer Lifetime Value"]
    .astype(str)
    .str.replace("%", "", regex=False)
)

df_final["Customer Lifetime Value"] = pd.to_numeric(
    df_final["Customer Lifetime Value"],
    errors="coerce"
)

# %%
df_final.isnull().sum()
# Out:
# Customer                        0
# Education                       0
# Customer Lifetime Value      7077
# Income                          0
# Monthly Premium Auto            0
# Number of Open Complaints       0
# Policy Type                     0
# Vehicle Class                   0
# Total Claim Amount              0
# State                           0
# Gender                        122
# dtype: int64

# %%
df_new["Customer Lifetime Value"].isnull().sum()
# Out:
# np.int64(2944)

# %%
df_new["Customer Lifetime Value"].head(10)
# Out:
# 0            NaN
# 1     697953.59%
# 2    1288743.17%
# 3     764586.18%
# 4     536307.65%
# 5     825629.78%
# 6     538089.86%
# 7     721610.03%
# 8    2412750.40%
# 9     738817.81%
# Name: Customer Lifetime Value, dtype: object

# %%
df_clean = df_new.copy()

# %%
df_clean = df_clean.dropna(how="all")

# %%
df_clean.shape
# Out:
# (9137, 11)

# %%
df_clean["Customer Lifetime Value"].isnull().sum()
# Out:
# np.int64(7)

# %%
df_clean["Customer Lifetime Value"] = (
    df_clean["Customer Lifetime Value"]
    .astype(str)
    .str.replace("%", "", regex=False)
)

# %%
df_clean["Customer Lifetime Value"] = pd.to_numeric(
    df_clean["Customer Lifetime Value"],
    errors="coerce"
)

# %%
df_clean["Customer Lifetime Value"].dtype
# Out:
# dtype('float64')

# %%
df_clean["Customer Lifetime Value"].isnull().sum()
# Out:
# np.int64(7)

# %%
print("Mean:", df_clean["Customer Lifetime Value"].mean())
print("Median:", df_clean["Customer Lifetime Value"].median())
# Out:
# Mean: 182196.3896898556
# Median: 7714.8768635

# %%
df_clean["Customer Lifetime Value"] = df_clean["Customer Lifetime Value"].fillna(
    df_clean["Customer Lifetime Value"].median()
)

# %%
df_clean["Customer Lifetime Value"].isnull().sum()
# Out:
# np.int64(0)

# %%
df_clean["Gender"].value_counts()
# Out:
# Gender
# F    4607
# M    4408
# Name: count, dtype: int64

# %%
df_clean["Gender"].mode()
# Out:
# 0    F
# Name: Gender, dtype: str

# %%
df_clean["Gender"] = df_clean["Gender"].fillna(
    df_clean["Gender"].mode()[0]
)

# %%
df_clean.isnull().sum()
# Out:
# Customer                     0
# Education                    0
# Customer Lifetime Value      0
# Income                       0
# Monthly Premium Auto         0
# Number of Open Complaints    0
# Policy Type                  0
# Vehicle Class                0
# Total Claim Amount           0
# State                        0
# Gender                       0
# dtype: int64

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(3)

# %%
df_clean = df_clean.drop_duplicates(keep="first")

# %%
print(df_clean.shape)
print(df_clean.duplicated().sum())
# Out:
# (9134, 11)
# 0

# %%
df_clean.dtypes
# Out:
# Customer                         str
# Education                        str
# Customer Lifetime Value      float64
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                      str
# Vehicle Class                    str
# Total Claim Amount           float64
# State                            str
# Gender                           str
# dtype: object

# %%
df_clean["Number of Open Complaints"] = df_clean["Number of Open Complaints"].apply(
    lambda x: x.split("/")[1] if isinstance(x, str) and "/" in x else x
)

# %%
df_clean["Number of Open Complaints"].unique()
# Out:
# array(['0', '2', '1', '3', '5', '4', 0, 2, 3, 1, 5, 4], dtype=object)

# %%
df_clean["Number of Open Complaints"] = pd.to_numeric(
    df_clean["Number of Open Complaints"]
)

# %%
df_clean["Number of Open Complaints"].dtype
# Out:
# dtype('int64')

# %%
numeric_columns = [
    "Customer Lifetime Value",
    "Income",
    "Monthly Premium Auto",
    "Total Claim Amount"
]

df_clean[numeric_columns] = df_clean[numeric_columns].astype(int)

# %%
df_clean.dtypes
# Out:
# Customer                       str
# Education                      str
# Customer Lifetime Value      int64
# Income                       int64
# Monthly Premium Auto         int64
# Number of Open Complaints    int64
# Policy Type                    str
# Vehicle Class                  str
# Total Claim Amount           int64
# State                          str
# Gender                         str
# dtype: object

# %%
print("Shape:", df_clean.shape)
print("Null values:")
print(df_clean.isnull().sum())

print("\nDuplicates:", df_clean.duplicated().sum())

print("\nData types:")
print(df_clean.dtypes)
# Out:
# Shape: (9134, 11)
# Null values:
# Customer                     0
# Education                    0
# Customer Lifetime Value      0
# Income                       0
# Monthly Premium Auto         0
# Number of Open Complaints    0
# Policy Type                  0
# Vehicle Class                0
# Total Claim Amount           0
# State                        0
# Gender                       0
# dtype: int64
#
# Duplicates: 0
#
# Data types:
# Customer                       str
# Education                      str
# Customer Lifetime Value      int64
# Income                       int64
# Monthly Premium Auto         int64
# Number of Open Complaints    int64
# Policy Type                    str
# Vehicle Class                  str
# Total Claim Amount           int64
# State                          str
# Gender                         str
# dtype: object

# %%
df_clean.head()
# Out:
#   Customer             Education  Customer Lifetime Value  Income  \
# 0  RB50392                Master                     7714       0
# 1  QZ44356              Bachelor                   697953       0
# 2  AI49188              Bachelor                  1288743   48767
# 3  WW63253              Bachelor                   764586       0
# 4  GA49547  High School or Below                   536307   36357
#
#    Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# 0                  1000                          0   Personal Auto
# 1                    94                          0   Personal Auto
# 2                   108                          0   Personal Auto
# 3                   106                          0  Corporate Auto
# 4                    68                          0   Personal Auto
#
#    Vehicle Class  Total Claim Amount       State Gender
# 0  Four-Door Car                   2  Washington      F
# ...

# %%
df_clean.to_csv("cleaned_data.csv", index=False)

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
import pandas as pd

url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv"

df_marketing = pd.read_csv(url)

# %%
df_marketing.shape
# Out:
# (10910, 27)

# %%
df_marketing.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
df_marketing.dtypes
# Out:
# unnamed:_0                         int64
# customer                             str
# state                                str
# customer_lifetime_value          float64
# response                             str
# coverage                             str
# education                            str
# effective_to_date                    str
# employmentstatus                     str
# gender                               str
# income                             int64
# location_code                        str
# marital_status                       str
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                          str
# policy                               str
# renew_offer_type                     str
# sales_channel                        str
# total_claim_amount               float64
# ...

# %%
df_marketing.isnull().sum()
# Out:
# unnamed:_0                       0
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# month                            0
# ...

# %%
df_marketing.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_marketing["unnamed:_0"].nunique()
# Out:
# 10910

# %%
df_marketing = df_marketing.drop(columns=["unnamed:_0"])

# %%
df_marketing.shape
# Out:
# (10910, 26)

# %%
df_marketing.duplicated().sum()
# Out:
# np.int64(443)

# %%
df_marketing[df_marketing.duplicated(keep=False)].sort_values("customer").head(20)
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 3960  AA10041  California              7901.744238       No     Basic
# 8731  AA10041  California              7901.744238       No     Basic
# 7527  AE74442  California              7379.456823       No     Basic
# 6792  AE74442  California              7379.456823       No     Basic
# 802   AI49712  Washington              2593.897887       No     Basic
# 8719  AI49712  Washington              2593.897887       No     Basic
# 3500  AK59340  California              5601.138061       No     Basic
# 3577  AK59340  California              5601.138061       No     Basic
# 6015  AK59340  California              5601.138061       No     Basic
# 8474  AK59340  California              5601.138061       No     Basic
# 5213  AL78075      Oregon              3810.238281       No   Premium
# 2608  AL78075      Oregon              3810.238281       No   Premium
# ...

# %%
df_marketing[df_marketing.duplicated(keep=False)].shape
# Out:
# (858, 26)

# %%
df_marketing = df_marketing.drop_duplicates(keep="first")

# %%
df_marketing = df_marketing.reset_index(drop=True)

# %%
print(df_marketing.shape)
print(df_marketing.duplicated().sum())
# Out:
# (10467, 26)
# 0

# %%
df_marketing["effective_to_date"] = pd.to_datetime(
    df_marketing["effective_to_date"]
)

# %%
df_marketing["effective_to_date"].dtype
# Out:
# dtype('<M8[us]')

# %%
df_marketing[["effective_to_date", "month"]].head(10)
# Out:
#   effective_to_date  month
# 0        2011-02-18      2
# 1        2011-01-18      1
# 2        2011-02-10      2
# 3        2011-01-11      1
# 4        2011-01-17      1
# 5        2011-02-14      2
# 6        2011-02-14      2
# 7        2011-02-24      2
# 8        2011-01-19      1
# 9        2011-01-04      1

# %%
df_marketing["education"].value_counts()
# Out:
# education
# Bachelor                3127
# College                 3059
# High School or Below    3026
# Master                   866
# Doctor                   389
# Name: count, dtype: int64

# %%
df_marketing["vehicle_class"].value_counts()
# Out:
# vehicle_class
# Four-Door Car    5498
# Two-Door Car     2074
# SUV              1972
# Sports Car        537
# Luxury SUV        203
# Luxury Car        183
# Name: count, dtype: int64

# %%
##Question 1

# Create a pivot table with total revenue by sales channel

revenue_by_channel = df_marketing.pivot_table(
    index="sales_channel",
    values="total_claim_amount",
    aggfunc="sum"
)

# Round to 2 decimal places
revenue_by_channel = revenue_by_channel.round(2)

# Display the result
print(revenue_by_channel)
# Out:
#                total_claim_amount
# sales_channel
# Agent                  1748923.49
# Branch                 1259333.44
# Call Center             889094.77
# Web                     676658.10

# %%
### Analysis

The pivot table shows the total claim amount for each sales channel.
The sales channel with the highest total value represents the largest
contribution to the total amount in the dataset.

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
## Question 2

# Create a pivot table with average Customer Lifetime Value
# by gender and education level

clv_gender_education = df_marketing.pivot_table(
    index="gender",
    columns="education",
    values="customer_lifetime_value",
    aggfunc="mean"
)

# Round to 2 decimal places
clv_gender_education = clv_gender_education.round(2)

# Display the result
print(clv_gender_education)
# Out:
# education  Bachelor  College   Doctor  High School or Below   Master
# gender
# F           7913.45  7755.03  7369.59               8616.66  8226.36
# M           7713.30  8086.29  7414.86               8162.36  8154.61

# %%
### Analysis

The pivot table compares the average Customer Lifetime Value across 
gender and education levels. The results show differences in average
CLV between the different customer segments.

# %% [markdown]
# ### Analysis Question 1 — Total Revenue by Sales Channel
#
# The Agent sales channel has the highest total revenue, with 1,748,923.49,
# followed by Branch with 1,259,333.44.
#
# Call Center generated 889,094.77, while Web had the lowest total revenue
# at 676,658.10.
#
# Based on the results, Agent is the leading sales channel in terms of
# total revenue.

# %% [markdown]
# ### Analysis Question 2 — Average Customer Lifetime Value by Gender and Education
#
# The average Customer Lifetime Value varies across gender and education levels.
#
# Female customers with a High School education or below have the highest
# average CLV at 8,616.66. For male customers, the highest average CLV is
# also found in the High School or Below group, at 8,162.36.
#
# Customers with a Doctor education level have the lowest average CLV for
# both genders.
#
# There is no consistent pattern showing that one gender has a higher CLV
# across all education levels. This suggests that both gender and education
# should be considered when analyzing customer value.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
